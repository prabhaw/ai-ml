# %%
import pandas as pa
pa.set_option('display.max_rows', None)
df = pa.read_excel("/content/customer_call_list.xlsx")
df.drop_duplicates(inplace=True)
del df["Not_Useful_Column"]
df = df.fillna("")
df["Last_Name"] = df["Last_Name"].str.strip("/")
df['Phone_Number']= df["Phone_Number"].str.replace('[^a-zA-Z0-9]', '', regex=True)
df['Phone_Number'] = df['Phone_Number'].str.replace("Na", "")
df['Phone_Number'] = df['Phone_Number'].astype(str)
df['Phone_Number'] = df['Phone_Number'].str.replace("nan", "")
df["Phone_Number"]= df['Phone_Number'].apply(lambda x:  x[0:3] + "-" + x[3:6] + "-" + x[6:10] if x != 'nan' and x != '' else x)
df['Last_Name'] = df['Last_Name'].str.replace("[^a-zA-Z]", '', regex=True)
df['street_address'] = df['Address'].apply(lambda x: x.split(",")[0])
df['state'] = df['Address'].apply(lambda x: x.split(',')[1] if len(x.split(',')) >= 2 else "")
df['zip_code'] = df['Address'].apply(lambda x: x.split(',')[2] if len(x.split(',')) >= 3 else "")
df["Do_Not_Contact"] = df["Do_Not_Contact"].apply(lambda x: "Y" if x == "Yes" or x == "yes" else x)
df["Do_Not_Contact"] = df["Do_Not_Contact"].apply(lambda x: "N" if x == "No" or x == "no" else x)
df = df.replace("N/a", "")
df = df[df['Phone_Number'] != '']
df.reset_index(inplace=True)
df
# Out:
#     index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0       0        1001      Frodo     Baggins  123-545-5421
# 1       1        1002       Abed       Nadir  123-643-9775
# 2       3        1004     Dwight     Schrute  123-543-2345
# 3       4        1005        Jon        Snow  876-678-3469
# 4       5        1006        Ron     Swanson  304-762-2467
# 5       7        1008   Sherlock      Holmes  876-678-3469
# 6       9        1010      Peter      Parker  123-545-5421
# 7      12        1013        Don      Draper  123-543-2345
# 8      13        1014     Leslie       Knope  876-678-3469
# 9      14        1015       Toby  Flenderson  304-762-2467
# 10     15        1016        Ron     Weasley  123-545-5421
# 11     16        1017   Michael        Scott  123-643-9775
# 12     19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# ...
